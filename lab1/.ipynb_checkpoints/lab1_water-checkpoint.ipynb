# %%
options(repr.plot.width = 4, repr.plot.height = 3)

# %%
water_data <- read.csv("./data/water-treatment.csv")
tail(water_data, 5)
head(water_data, 5)
attach(water_data)
# Out:
#     DATE      Q.E   ZN.E PH.E DBO.E DQO.E SS.E SSV.E SED.E COND.E ⋯ COND.S
# 523 D-26/8/91 32723 0.16 7.7  93    252   176  56.8  2.3    894   ⋯ 942
# 524 D-27/8/91 33535 0.32 7.8  192   346   172  68.6  4.0    988   ⋯ 950
# 525 D-28/8/91 32922 0.30 7.4  139   367   180  64.4  3.0   1060   ⋯ 1136
# 526 D-29/8/91 32190 0.30 7.3  200   545   258  65.1  4.0   1260   ⋯ 1326
# 527 D-30/8/91 30488 0.21 7.5  152   300   132  69.7  ?     1073   ⋯ 1224
#     RD.DBO.P RD.SS.P RD.SED.P RD.DBO.S RD.DQO.S RD.DBO.G RD.DQO.G RD.SS.G
# 523 ?        62.3    93.3     69.8     75.9     79.6     78.6     96.6
# 524 ?        58.3    97.8     83.0     59.1     91.1     74.6     90.7
# 525 ?        65.0    97.1     76.2     66.4     82.0     77.1     88.9
# 526 39.8     65.9    97.1     81.7     70.9     89.5     87.0     89.5
# 527 ?        69.5    ?        81.7     76.4     ?        81.7     86.4
#     RD.SED.G
# 523 99.6
# 524 100
# 525 99
# 526 99.8
# 527 ?
# ...

# %%
length(ZN.E)
# Out:
# [1] 527

# %%
zne <- ZN.E[(!is.na(ZN.E)) & (ZN.E != '?')]  # Filtering

# %%
length(zne)
# Out:
# [1] 524

# %%
plot(ecdf(zne), do.points=FALSE, verticals=TRUE)
# Out:
# Plot with title “ecdf(zne)”

# %%
boxplot(PH.E[PH.E!= '?'], PH.D[PH.D!='?'])
qqplot(PH.E[PH.E!= '?'], PH.D[PH.D!='?'])
# Out:
# plot without title
# plot without title
